# %%
import numpy as np

from numpy_clustering_functions import assign_data_to_cluster

#dummy_data = np.array([[1.0, 2.0], [1.4, 1.8], [5.0, 8.0], [8.0, 8.0], [6.5, 8.0], [12,1], [16,21], [100,50],[1000,1000]])
dummy_data = np.array([[1.0, 2.0], [1.4, 1.8], [5.0, 8.0], [8.0, 8.0], [6.5, 8.0]])
dummy_centers = np.array([[1.2, 1.9], [6.5, 8.0]])
dummy_ids = np.array([0, 0, 1, 1, 1])

lbls=np.array([1,2])

t= assign_data_to_cluster(dummy_data, dummy_centers, lbls)
print(t)

#d=compute_distance_to_centers(dummy_data, dummy_centers)

#print(d)

a= [4, 3, 5, 7, 6, 8]

ind=[0, 1, 4,5,5,4,4]
r=np.take(a,ind)
print(r)
# Out:
# [0 0 1 1 1]
